# %% [markdown]
# <a href="https://colab.research.google.com/gist/Tung511/b6f3802117b8e838903edd1db321752e/ai-w5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
# !pip install scikit-fuzzy
import skfuzzy as fuzz
from skfuzzy import control as ctrl 
universe = np.linspace(0,10,60)
universe_1 = np.linspace(10,30,61)
food = ctrl.Antecedent(universe,'Food')
service = ctrl.Antecedent(universe,'Service')
tip = ctrl.Antecedent(universe,'Tip')
names = ['VP','P','AV','G','VG']
food.automf(names = names)  # chi lam so le
service.automf(names = names)
tip.automf(names = names)
food.view()
service.view()
tip.view()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
rule0 =ctrl.Rule(antecedent=((food['VP'] & service['VP'])|(food['VP'] & service['P'])|(food['P'] & service['VP'])),consequent=tip['VP'],label='rule P')
rule1 =ctrl.Rule(antecedent=((food['AV'] & service['VP'])|(food['G'] & service['VP'])|(food['AV'] & service['P'])|(food['P'] & service['AV'])|(food['G'] & service['VP'])),consequent=tip['P'],label='rule vp')

# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl
universe = np.linspace(0,10,61)
universe1 = np.linspace(-2,2,5)
alpha= ctrl.Antecedent(universe,'alpha')
dalpha= ctrl.Consequent(universe1,'dalpha')
names=['ln','n','ze','p','lp']
alpha.automf(names=names)
dalpha.automf(names=names)
alpha.view()
dalpha.view()
